# %%
import pandas as pd
         
CSV_FILE = 'test_results_with_questions.csv'

fieldnames = [
    'section', 'dataset', 'embedder', 'chunking_detail', 'timestamp', 'extra_info', 'device', 'evalmodel', 'Prompt', 'ModelName',
    'Temperature', 'TopK', 'SimilarityThresholdDocuments',
    'SimilarityThresholdQuestions', 'runId', 'category',
    'TFIDFScore', 'ResponseTime', 'answer_correctness',
    'faithfulness', 'answer_similarity', 'answer_relevancy', 'context_precision',
    'context_relevancy', 'context_recall', 'response_json', 'similarityLevel']
# Read the CSV file into a DataFrame
df = pd.read_csv(CSV_FILE, usecols=fieldnames)

# Ensure numeric columns are indeed numeric
numeric_cols = [
    'TFIDFScore', 'ResponseTime', 'answer_similarity', 'answer_correctness'
]

# Convert the specified columns to numeric, coercing errors to NaN
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# # Drop rows with NaN values in numeric columns to avoid issues during aggregation
# df = df.dropna(subset=numeric_cols)

comparison_df = df.groupby(['extra_info'])[numeric_cols].mean().reset_index()

print(comparison_df)
print(df.shape[0])
# Out:
#       extra_info  TFIDFScore  ResponseTime  answer_similarity  \
# 0    no_question    0.296113   4547.795094           0.664729
# 1  with_question    0.437722   4409.581180           0.736551
#
#    answer_correctness
# 0            0.463972
# 1            0.640519
# 1479

# %%
import pandas as pd
import json

# Read the CSV file into a DataFrame
CSV_FILE = 'test_results_with_questions.csv'

fieldnames = [
    'section', 'dataset', 'embedder', 'chunking_detail', 'timestamp', 'extra_info', 'device', 'evalmodel', 'Prompt', 'ModelName',
    'Temperature', 'TopK', 'SimilarityThresholdDocuments',
    'SimilarityThresholdQuestions', 'runId', 'category',
    'TFIDFScore', 'ResponseTime', 'answer_correctness',
    'faithfulness', 'answer_similarity', 'answer_relevancy', 'context_precision',
    'context_relevancy', 'context_recall', 'response_json', 'similarityLevel'
]

# Read the CSV file into a DataFrame
df = pd.read_csv(CSV_FILE, usecols=fieldnames)

# Ensure numeric columns are indeed numeric
numeric_cols = [
    'TFIDFScore', 'ResponseTime', 'answer_similarity', 'answer_correctness', 'similarityLevel',
]

# Convert the specified columns to numeric, coercing errors to NaN
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# Filter the DataFrame by 'extra_info' and similarityLevel
df = df[df['similarityLevel'] < 0.5]
no_question_df = df[df['extra_info'] == 'no_question']
with_question_df = df[df['extra_info'] == 'with_question']

# Function to extract question from response_json
def extract_question(json_str):
    try:
        data = json.loads(json_str)
        return data.get('question', None)
    except json.JSONDecodeError:
        return None

# Extract questions for merging
no_question_df['question'] = no_question_df['response_json'].apply(extract_question)
with_question_df['question'] = with_question_df['response_json'].apply(extract_question)

# Merge the two DataFrames on question
merged_df = no_question_df.merge(
    with_question_df,
    on='question',
    suffixes=('_no', '_with')
)

# Calculate the difference in TFIDFScore
merged_df['TFIDF_diff'] = abs(merged_df['TFIDFScore_with'] - merged_df['TFIDFScore_no'])

# Rank by the difference in TFIDFScore
top_5_diff = merged_df.nlargest(10, 'TFIDF_diff')

# Log the top 5 results with TFIDF difference and response_json for both sections
top_5_results = top_5_diff[['question', 'TFIDF_diff', 'response_json_no', 'response_json_with']]

# Print the top 5 results
print(top_5_results.to_string(index=False))

# Print detailed information
for index, row in top_5_results.iterrows():
    print(f"Question: {row['question']}")
    print(f"TFIDF Difference: {row['TFIDF_diff']}")
    print(f"No Question Response JSON: {row['response_json_no']}")
    print(f"With Question Response JSON: {row['response_json_with']}")
    print("-" * 80)
# Out:
#                                                                      question  TFIDF_diff                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    response_json_no                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
#                 Should the number 0 be included in the count of even numbers?    0.783718                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {"question": "Should the number 0 be included in the count of even numbers?", "answer": "I'm not sure, but this is what I think. \n\nThe method `myMethod` prints the digits of a given integer `n` in reverse order. It does this by recursively calling itself with the argument `n / 10` until `n` is no longer greater than 0, at which point it stops recursing and returns.", "sourceDocuments": [{"content": "COSC 121. Page 37\nClicker Question\nWhat are the base cases in the following recursive method?\npublic static void myMethod(intn) {\nif (n > 0) {\nSystem.out.print(n % 10);\nmyMethod(n / 10);\n}\n}\nA.n > 0\nB.n <= 0\nC.no base cases\nD.n < 0\nQ: What does this method do?", "docName": "L11_Recursion_A_(ch18)", "sourceLink": "testSource", "pageNumbers": [36, 10, 32]}], "courseId": "COSC121"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
#                  Can you explain an efficient method to find perfect numbers?    0.586940                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {"question": "Can you explain an efficient method to find perfect numbers?", "answer": "I don't know. The provided context does not mention perfect numbers or provide a specific algorithm for finding them. It discusses algorithms efficiency, best/average/worst case analysis, and good programming methods, but it does not offer a solution to the problem of finding perfect numbers.", "sourceDocuments": [{"content": "COSC 121. Page 6\nAlgorithms Efficiency", "docName": "L19_Sorting_A_(ch23)", "sourceLink": "testSource", "pageNumbers": [4, 10]}, {"content": "COSC 121. Page 45\nCOSC 222 Goals\nSolving problems using programming.\nWriting efficient programs (in terms of speed and memory usage)\nGood programming method:\n\u25aaproblem solving\n\u25aadesign\n\u25aatesting\n\u25aaprogramming\nBloom\u2019s Revised Taxonomy", "docName": "RevisionFinal_clickers_solved", "sourceLink": "testSource", "pageNumbers": [42]}], "courseId": "COSC121"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
#                    How can the program efficiently check for perfect numbers?    0.582481                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           {"question": "How can the program efficiently check for perfect numbers?", "answer": "I don't know. The provided context does not mention perfect numbers or how to efficiently check for them. It discusses algorithms, performance, and efficiency in general terms, but it does not provide specific information about perfect numbers.", "sourceDocuments": [{"content": "COSC 121. Page 11\nWhy are some programs faster than others?\nExample3: data sorting\n\u2022http://www.sorting-algorithms.com/\n\u2022http://blocks.org/andrewringler/raw/3809399/\nIn general, the performance of an algorithm when implemented \non a computer depends on the approach used to solve the \nproblem and the actual steps taken.\nAlthough faster hardware makes all algorithms faster, algorithms \nthat solve the same problem can be compared in a hardware-\nindependent wayusing big-Ohnotation.", "docName": "L19_Sorting_A_(ch23)", "sourceLink": "testSource", "pageNumbers": [9, 4]}, {"content": "COSC 121. Page 45\nCOSC 222 Goals\nSolving problems using programming.\nWriting efficient programs (in terms of speed and memory usage)\nGood programming method:\n\u25aaproblem solving\n\u25aadesign\n\u25aatesting\n\u25aaprogramming\nBloom\u2019s Revised Taxonomy", "docName": "RevisionFinal_clickers_solved", "sourceLink": "testSource", "pageNumbers": [42]}], "courseId": "COSC121"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
#              What are the times and locations for TA office hours in COSC304?    0.538413                                                                                                                                                                                                                                                                                          {"question": "What are the times and locations for TA office hours in COSC304?", "answer": "The Virtual Drop-in Session Hours for TAs/Instructors are:\n\nMonday 9-11 am - Eranga Desaa/Omar Abdelaziz\nMonday 2-4 pm - Justin Schoenit/Kevin Wang\nTuesday 2-4 pm - Eranga Desaa/Omar Abdelaziz\nWednesday 2-4 pm - Eranga Desaa/Omar Abdelaziz\nFriday 1-3 pm - Justin Schoenit\n\nNote that these are virtual drop-in sessions, not specifically \"office hours\". If you're looking for office hours, Dr. Ramon Lawrence has office hours on Thursdays from 2 to 4 p.m., both in-person (ASC 349) and online.", "sourceDocuments": [{"content": "COSC 304 - Introduction to Databases -\nSeptember 2023\nInstructor\nDr. Ramon Lawrence, ramon.lawrence@ubc.ca, 250-807-9390\n \nLive Classroom Schedule: 11:00 a.m. to 12:30 p.m Tuesday/Thursday\n \nMode of Delivery: FIP 204 and live-stream on Zoom\n \nOffice Hours: Thursdays 2 to 4 p.m. (in-person and online)\n \nOffice Location: ASC 349\n \nCalendar Course Description from the UBCO Calendar: http://www.calendar.ubc.ca/okanagan/courses.cfm?go=name&code=COSC\n(https://okanagan.calendar.ubc.ca/course-descriptions/subject/cosc)\nVirtual Drop-in Session Hours\nDay/TimeTA/Instructor\nMonday 9 to 11 a.m.Eranga Desaa  /  Omar Abdelaziz\nMonday 2 to 4 p.m.Justin Schoenit / Kevin Wang\nTuesday 11 a.m. to 12:30 p.m. (class time)Justin Schoenit\nTuesday 2 to 4 p.m.Eranga Desaa  /  Omar Abdelaziz\nWednesday 2 to 4 p.m.Eranga Desaa  /  Omar Abdelaziz\nThursday 11 a.m. to 12:30 p.m. (class time)Omar Abdelazi\nThursday 2 to 4 p.m.Dr. Ramon Lawrence (virtual and in-person)\nFriday 1 to 3 p.m.Justin Schoenit", "docName": "304Syllabus", "sourceLink": " https://github.com/wskksw/cosc_304/raw/main/304Syllabus.pdf", "pageNumbers": [1]}, {"content": "9\nThe Lab Assignments\nThe lab assignments are critical to learning the material and are \ndesigned to build up your skills and prepare you for the exams.\nThe weekly lab assignments are worth 20%of your overall grade. \nYou have until the week after the lab is assigned to complete it.  \n\u2022No late assignments will be accepted.  \n\u2022An assignment may be handed in any time before the due date and may be \nmarked immediately by the TA.\n\u2022Lab assignments may take between 2 and 10 hours depending on the lab.\nLab assignments are done in pairs. \nThere is no scheduled lab time.TA help desk hours are posted.", "docName": "304_1_Intro", "sourceLink": "testSource", "pageNumbers": [9]}, {"content": "1\nCourse Summary and\nCOSC 404\nCOSC 304 \u2013 Introduction to Database Systems", "docName": "304_25_Course_Summary", "sourceLink": "testSource", "pageNumbers": [1]}], "courseId": "COSC304"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
#    What should I do if I get a 'Permission denied' error for jjtree on macOS?    0.520970                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        {"question": "What should I do if I get a 'Permission denied' error for jjtree on macOS?", "answer": "I don't know. The provided context does not mention \"jjtree\" or \"macOS\", and it appears to be related to B-trees and database system implementation, which is unrelated to the question being asked.", "sourceDocuments": [{"content": "1\nR-trees\nCOSC 404 \u2013 Database System Implementation", "docName": "404_5_RTrees", "sourceLink": "testSource", "pageNumbers": [1]}, {"content": "1\nB-trees\nCOSC 404 \u2013 Database System Implementation", "docName": "404_4_BTrees", "sourceLink": "testSource", "pageNumbers": [1, 48]}], "courseId": "COSC404"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
#                                How do you handle grade ties in student marks?    0.519120                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           {"question": "How do you handle grade ties in student marks?", "answer": "I don't know. The provided context does not mention how to handle grade ties in student marks. It discusses grading practices, excused absences, and late assignments, but it does not address the specific issue of handling grade ties.", "sourceDocuments": [{"content": "Grading Practices: Faculties, departments, and schools reserve the right to scale grades in order to maintain \nequity among sections and conformity to University, faculty, department, or school norms. Students should \ntherefore note that an unofficial grade given by an instructor might be changed by the faculty, department, \nor school. Grades are not official until they appear on a student\u2019s academic record: \nhttp://www.calendar.ubc.ca/okanagan/index.cfm?tree=3,41,90,1014 \nFaculties, departments, and schools reserve the right to scale grades in order to maintain equity among \nsections and conformity to university, faculty, department, or school norms. Students should therefore note \nthat an unofficial grade given by an instructor might be changed by the faculty, department, or school. \nGrades are not official until they appear on a student's academic record.  \nhttp://www.calendar.ubc.ca/okanagan/index.cfm?tree=3,41,90,1014", "docName": "syllabus", "sourceLink": "testSource", "pageNumbers": [7, 2]}, {"content": "COSC 111. Page 24\nLiang, Introduction to Java Programming, Tenth Edition, (c) 2015 Pearson Education, Inc. \nPractice\nWrite a program that grades multiple-choice test. \nAssume the following data is given and you are required to \ndisplay the grade for each student.\nStudents\u2019 Answers", "docName": "L17_nDArrays_(ch8)", "sourceLink": "testSource", "pageNumbers": [23]}], "courseId": "COSC111"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# How to handle log records with before and after values in undo-redo recovery?    0.508012                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    {"question": "How to handle log records with before and after values in undo-redo recovery?", "answer": "I don't know. The provided context does not explicitly explain how to handle log records with before and after values in undo-redo recovery. It only provides examples of undo/redo recovery and the steps involved in the process, but it does not specifically address this question.", "sourceDocuments": [{"content": "18\nUndo/Redo Recovery Example\nThe log as it appears at three instances of time:\nRecovery actions in each case above are:\n\u2022(a) undo (T\n0\n): B is restored to 2000 and A to 1000.\n\u2022(b) redo (T\n0\n) and undo (T\n1\n): Aset to 950 and Bset to 2050 then Cis restored to 700.\n\u2022(c) redo (T\n0\n) and redo (T\n1\n): A and B are set to 950 and 2050 respectively. Then Cis set \nto 600.\n<T\n0\nstart>\n<T\n0\n, A, 1000, 950>\n<T\n0\n, B, 2000, 2050>\n<T\n0\nstart>\n<T\n0\n, A, 1000, 950>\n<T\n0\n, B, 2000, 2050>\n<T\n0\ncommit>\n<T\n1\nstart>\n<T\n1\n, C, 700, 600>\n<T\n0\nstart>\n<T\n0\n, A, 1000, 950>\n<T\n0\n, B, 2000, 2050>\n<T\n0\ncommit>\n<T\n1\nstart>\n<T\n1\n, C, 700, 600> \n<T\n1\ncommit>\n(a)\n(b)\n(c)", "docName": "404_12_Recovery", "sourceLink": "testSource", "pageNumbers": [18, 17, 24]}], "courseId": "COSC404"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
#                                 How should ties in student grades be handled?    0.506993                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {"question": "How should ties in student grades be handled?", "answer": "I don't know. The provided context does not mention how to handle ties in student grades. It discusses grading practices, excused absences, late assignments, and grievance procedures, but does not address the specific issue of tied grades.", "sourceDocuments": [{"content": "Grading Practices: Faculties, departments, and schools reserve the right to scale grades in order to maintain \nequity among sections and conformity to University, faculty, department, or school norms. Students should \ntherefore note that an unofficial grade given by an instructor might be changed by the faculty, department, \nor school. Grades are not official until they appear on a student\u2019s academic record: \nhttp://www.calendar.ubc.ca/okanagan/index.cfm?tree=3,41,90,1014 \nFaculties, departments, and schools reserve the right to scale grades in order to maintain equity among \nsections and conformity to university, faculty, department, or school norms. Students should therefore note \nthat an unofficial grade given by an instructor might be changed by the faculty, department, or school. \nGrades are not official until they appear on a student's academic record.  \nhttp://www.calendar.ubc.ca/okanagan/index.cfm?tree=3,41,90,1014", "docName": "syllabus", "sourceLink": "testSource", "pageNumbers": [7, 2]}], "courseId": "COSC111"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
#                        How should the noDuplicates method handle null values?    0.504558 {"question": "How should the noDuplicates method handle null values?", "answer": "I don't know. The context provided does not explicitly mention how to handle null values in the `noDuplicates` method. It only describes the method's purpose and signature, but does not provide implementation details or specific instructions for handling null values.", "sourceDocuments": [{"content": "Assignment A6 (25 marks) \nFocus: ArrayLists \nQ1. [10 marks] Write a method with the following header \n \npublic static ArrayList<Integer> noDuplicates(ArrayList<Integer> list) \n \nThe method returns a new array list that contains the non-duplicate elements of list. \nWrite  a  test  program  that prompts  the  user  to  enter  5 integers  to  a  list  and  displays the \ndistinct integers.  \nSample run \n \n \nQ2. [15 marks] Write a method that has the following header: \npublic static void printShuffled(String filename) \nThe method reads a text file, filename, sentence by sentence into an array list, shuffles \nthe sentences, and then prints out the shuffled contents. Assume sentences end with one of \nthese characters: \".\", \":\", \"!\" and \"?\". Your method should create an array list for storing the \nsentences.  The  array  list  should  be  created with  approximately  the  correct  number  of \nsentences, instead of being gradually expanded as the file is read in.", "docName": "A6", "sourceLink": "testSource", "pageNumbers": [1]}, {"content": "COSC 121. Page 20\nClicker Question\nWhat is the output of the following code?\nA.B.C.\nDuplicates are \nallowed!\nArrayList<String> x=new ArrayList<>(Arrays.asList(\"A\",\"B\",\"C\"));\nSystem.out.println(x);\nx.set(1, \"D\");\nx.add(\"D\");\nSystem.out.println(x);\nSystem.out.println(x.indexOf(\"C\"));\nSystem.out.println(x.indexOf(\"Z\"));\nSystem.out.println(x.remove(\"Z\"));\nSystem.out.println(x.remove(\"D\"));\nSystem.out.println(x);\n[A, B, C]\n[D, B, C, D]\n2\n-1\nfalse\ntrue\n[B, C, D]\n[A, B, C]\n[A, D, C, D]\n2\n-1\nfalse\ntrue\n[A, C, D]\n[A, B, C]\n[A, D, C, D]\n2\n-1\nfalse\ntrue\n[A, D, C]", "docName": "L13_Arraylists_IntroGenerics_A_(Ch11)", "sourceLink": "testSource", "pageNumbers": [20]}, {"content": "COSC 121. Page 39\nLiang, Introduction to Java Programming, Tenth Edition, (c) 2015 Pearson Education, Inc. \nPractice\n1) If you change the code in the ensureCapacityfrom\n\u25aaE[] newData = (E[])(new Object[size * 2 + 1]);\nto\n\u25aaE[] newData = (E[])(new Object[size * 2]);\nthe program is incorrect. Can you find the reason?\nHint: consider an ArrayListafter calling clear() then trimToSize()\n2) Add a method to MyArrayListwith the following header:\nintremoveDuplicates()\nThe method should remove all duplicates from the array list. \nAssume that you have a constructor that MyArrayList(intn) \nwhere n is the initial number of elements.", "docName": "L18_implListsStacksQueues_B_(ch24)", "sourceLink": "testSource", "pageNumbers": [37]}], "courseId": "COSC121"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
#                   What might be wrong with my wind-chill calculation in Java?    0.501440                                                                                                                                                                                                                                                                   {"question": "What might be wrong with my wind-chill calculation in Java?", "answer": "Based on the provided context, I'm going to answer your question.\n\nWhat might be wrong with your wind-chill calculation in Java?\n\nI don't know. The context provides a formula for calculating wind-chill temperature and hints at using Math.pow() for the calculation, but it doesn't provide any specific Java code or errors that might be wrong with the calculation.", "sourceDocuments": [{"content": "A3 [30 marks]  \nFocus: arithmetic operators, Math class, printf () method \nQ1. [6 marks] The evaluation of the cold of our environment relies on several elements such as \nrelative humidity, speed of wind, and sunshine. To calculate the wind-chill temperature using \nwind and temperature, the formula below is used: \n   T\nwc\n = 35.74 + 0.6215 t\na\n - 35.75 v\n0.16\n + 0.4275 t\na\n v\n0.16\n  \nHere, v is the wind speed measured in mph and t\na\n is the exterior temperature measured in \ndegrees Fahrenheit. \n \nDevelop  a  program  that  takes  user  input  for  wind  speed  of  2  or  greater  and  temperature \nwhich is between -58 \u00baF and 41\u00baF and then calculates and prints the wind-chill temperature.  \nAssume the user will always enter a valid value, i.e. within the correct range. \nHint: You can use Math.pow (base value, power value).  \nSample run: \n \nQ2. [6 marks] Write a program that takes a real number as a user input and then prints the digits \nbefore and after the decimal point separately.", "docName": "A03", "sourceLink": "testSource", "pageNumbers": [1]}, {"content": "COSC 111. Page 43\nLiang, Introduction to Java Programming, Tenth Edition, (c) 2015 Pearson Education, Inc. \nPractice\nWrite a program that converts a Fahrenheit degree given by the \nuser to Celsius using the formula:\nAlgorithm:\n\u25aa1. Prompt the user for the Fahrenheit degree. Store the input \nin a variable. \n\u25aa2. Calculate the Celsius equivalent and store it in a variable\n\u25aa3. print out the Celsius degree. \n43\n)\n32\n)(\n(\n9\n5\n\u2212\n=\nfahrenheit\ncelsius\nAnswer:\nScanner input = ...\nSystem.out.println(\"Enter degrees in F\");\ndouble f = input.nextDouble();\ndouble c = (5.0/9) * (f-32);\nSystem.out.println(\"Degrees in C: \" + c);", "docName": "L3_Input_Constrants_Arithmetic_(ch2_part2)", "sourceLink": "testSource", "pageNumbers": [43]}, {"content": "COSC 111. Page 22\nLiang, Introduction to Java Programming, Tenth Edition, (c) 2015 Pearson Education, Inc. \nSimple Java Program 3\nAnimation\nOutput:\n0.39759036144578314", "docName": "L1.2_IntroToComputers_FirstProgram_(ch1_part1)", "sourceLink": "testSource", "pageNumbers": [22]}], "courseId": "COSC111"} {"question": "What might be wrong with my wind-chill calculation in Java?", "answer": "I don't know. The provided code seems correct, and the hint is to ensure the input values are within the specified range and correctly typed.", "sourceDocuments": [{"content": "I'm trying to calculate the wind-chill temperature in Java using the formula: `Twc = 35.74 + 0.6215 * ta - 35.75 * Math.pow(v, 0.16) + 0.4275 * ta * Math.pow(v, 0.16)`. Here's my code but I'm not getting the correct output: ``` import java.util.Scanner; public class Q1 { public static void main(String[] args) { Scanner input = new Scanner(System.in); System.out.print(\"Enter the temperature (between -58\u00b0F and 41\u00b0F): \"); double ta = input.nextDouble(); System.out.print(\"Enter the wind speed (2 mph or greater): \"); double v = input.nextDouble(); double Twc = 35.74 + 0.6215 * ta - 35.75 * Math.pow(v, 0.16) + 0.4275 * ta * Math.pow(v, 0.16); System.out.println(\"Th ...
# Question: Should the number 0 be included in the count of even numbers?
# TFIDF Difference: 0.783717550369489
# No Question Response JSON: {"question": "Should the number 0 be included in the count of even numbers?", "answer": "I'm not sure, but this is what I think. \n\nThe method `myMethod` prints the digits of a given integer `n` in reverse order. It does this by recursively calling itself with the argument `n / 10` until `n` is no longer greater than 0, at which point it stops recursing and returns.", "sourceDocuments": [{"content": "COSC 121. Page 37\nClicker Question\nWhat are the base cases in the following recursive method?\npublic static void myMethod(intn) {\nif (n > 0) {\nSystem.out.print(n % 10);\nmyMethod(n / 10);\n}\n}\nA.n > 0\nB.n <= 0\nC.no base cases\nD.n < 0\nQ: What does this method do?", "docName": "L11_Recursion_A_(ch18)", "sourceLink": "testSource", "pageNumbers": [36, 10, 32]}], "courseId": "COSC121"}
# With Question Response JSON: {"question": "Should the number 0 be included in the count of even numbers?", "answer": "No, the number 0 should not be included in the count of even numbers.", "sourceDocuments": [{"content": "For A5 Q1, the program should allow a user to enter numbers until they input 0. Should the number 0 be included in the count of even numbers, and how should the program handle multiple zero inputs? The number 0 should not be included in the count of even numbers, nor should it affect the sum and average calculations. If the user inputs multiple zeros, the program should simply continue to prompt for input without including these zeros in any of the calculations.", "sourceLink": "inserted_questions", "pageNumbers": [0]}, {"content": "COSC 121. Page 37\nClicker Question\nWhat are the base cases in the following recursive method?\npublic static void myMethod(intn) {\nif (n > 0) {\nSystem.out.print(n % 10);\nmyMethod(n / 10);\n}\n}\nA.n > 0\nB.n <= 0\nC.no base cases\nD.n < 0\nQ: What does this method do?", "docName": "L11_Recursion_A_(ch18)", "sourceLink": "testSource", "pageNumbers": [36]}], "courseId": "COSC121"}
# --------------------------------------------------------------------------------
# Question: Can you explain an efficient method to find perfect numbers?
# TFIDF Difference: 0.5869401323523051
# No Question Response JSON: {"question": "Can you explain an efficient method to find perfect numbers?", "answer": "I don't know. The provided context does not mention perfect numbers or provide a specific algorithm for finding them. It discusses algorithms efficiency, best/average/worst case analysis, and good programming methods, but it does not offer a solution to the problem of finding perfect numbers.", "sourceDocuments": [{"content": "COSC 121. Page 6\nAlgorithms Efficiency", "docName": "L19_Sorting_A_(ch23)", "sourceLink": "testSource", "pageNumbers": [4, 10]}, {"content": "COSC 121. Page 45\nCOSC 222 Goals\nSolving problems using programming.\nWriting efficient programs (in terms of speed and memory usage)\nGood programming method:\n\u25aaproblem solving\n\u25aadesign\n\u25aatesting\n\u25aaprogramming\nBloom\u2019s Revised Taxonomy", "docName": "RevisionFinal_clickers_solved", "sourceLink": "testSource", "pageNumbers": [42]}], "courseId": "COSC121"}
# ...
# --------------------------------------------------------------------------------
# Question: How should ties in student grades be handled?
# TFIDF Difference: 0.5069933440453811
# No Question Response JSON: {"question": "How should ties in student grades be handled?", "answer": "I don't know. The provided context does not mention how to handle ties in student grades. It discusses grading practices, excused absences, late assignments, and grievance procedures, but does not address the specific issue of tied grades.", "sourceDocuments": [{"content": "Grading Practices: Faculties, departments, and schools reserve the right to scale grades in order to maintain \nequity among sections and conformity to University, faculty, department, or school norms. Students should \ntherefore note that an unofficial grade given by an instructor might be changed by the faculty, department, \nor school. Grades are not official until they appear on a student\u2019s academic record: \nhttp://www.calendar.ubc.ca/okanagan/index.cfm?tree=3,41,90,1014 \nFaculties, departments, and schools reserve the right to scale grades in order to maintain equity among \nsections and conformity to university, faculty, department, or school norms. Students should therefore note \nthat an unofficial grade given by an instructor might be changed by the faculty, department, or school. \nGrades are not official until they appear on a student's academic record.  \nhttp://www.calendar.ubc.ca/okanagan/index.cfm?tree=3,41,90,1014", "docName": "syllabus", "sourceLink": "testSource", "pageNumbers": [7, 2]}], "courseId": "COSC111"}
# With Question Response JSON: {"question": "How should ties in student grades be handled?", "answer": "According to the context, when calculating letter grades based on student marks, all students with the highest mark should receive an 'A' grade. Therefore, ties in student grades should be handled by giving the same top grade (in this case, 'A') to all students who have achieved the highest mark.", "sourceDocuments": [{"content": "For A7 Q2, when calculating the letter grades based on student marks, should the program handle cases where there are ties in the highest mark? Yes, the program should handle cases where there are ties in the highest mark. All students with the highest mark should receive an 'A' grade.", "sourceLink": "inserted_questions", "pageNumbers": [0]}, {"content": "Grading Practices: Faculties, departments, and schools reserve the right to scale grades in order to maintain \nequity among sections and conformity to University, faculty, department, or school norms. Students should \ntherefore note that an unofficial grade given by an instructor might be changed by the faculty, department, \nor school. Grades are not official until they appear on a student\u2019s academic record: \nhttp://www.calendar.ubc.ca/okanagan/index.cfm?tree=3,41,90,1014 \nFaculties, departments, and schools reserve the right to scale grades in order to maintain equity among \nsections and conformity to university, faculty, department, or school norms. Students should therefore note \nthat an unofficial grade given by an instructor might be changed by the faculty, department, or school. \nGrades are not official until they appear on a student's academic record.  \nhttp://www.calendar.ubc.ca/okanagan/index.cfm?tree=3,41,90,1014", "docName": "syllabus", "sourceLink": "testSource", "pageNumbers": [7]}], "courseId": "COSC111"}
# --------------------------------------------------------------------------------
# Question: How should the noDuplicates method handle null values?
# TFIDF Difference: 0.504558365008347
# No Question Response JSON: {"question": "How should the noDuplicates method handle null values?", "answer": "I don't know. The context provided does not explicitly mention how to handle null values in the `noDuplicates` method. It only describes the method's purpose and signature, but does not provide implementation details or specific instructions for handling null values.", "sourceDocuments": [{"content": "Assignment A6 (25 marks) \nFocus: ArrayLists \nQ1. [10 marks] Write a method with the following header \n \npublic static ArrayList<Integer> noDuplicates(ArrayList<Integer> list) \n \nThe method returns a new array list that contains the non-duplicate elements of list. \nWrite  a  test  program  that prompts  the  user  to  enter  5 integers  to  a  list  and  displays the \ndistinct integers.  \nSample run \n \n \nQ2. [15 marks] Write a method that has the following header: \npublic static void printShuffled(String filename) \nThe method reads a text file, filename, sentence by sentence into an array list, shuffles \nthe sentences, and then prints out the shuffled contents. Assume sentences end with one of \nthese characters: \".\", \":\", \"!\" and \"?\". Your method should create an array list for storing the \nsentences.  The  array  list  should  be  created with  approximately  the  correct  number  of \nsentences, instead of being gradually expanded as the file is read in.", "docName": "A6", "sourceLink": "testSource", "pageNumbers": [1]}, {"content": "COSC 121. Page 20\nClicker Question\nWhat is the output of the following code?\nA.B.C.\nDuplicates are \nallowed!\nArrayList<String> x=new ArrayList<>(Arrays.asList(\"A\",\"B\",\"C\"));\nSystem.out.println(x);\nx.set(1, \"D\");\nx.add(\"D\");\nSystem.out.println(x);\nSystem.out.println(x.indexOf(\"C\"));\nSystem.out.println(x.indexOf(\"Z\"));\nSystem.out.println(x.remove(\"Z\"));\nSystem.out.println(x.remove(\"D\"));\nSystem.out.println(x);\n[A, B, C]\n[D, B, C, D]\n2\n-1\nfalse\ntrue\n[B, C, D]\n[A, B, C]\n[A, D, C, D]\n2\n-1\nfalse\ntrue\n[A, C, D]\n[A, B, C]\n[A, D, C, D]\n2\n-1\nfalse\ntrue\n[A, D, C]", "docName": "L13_Arraylists_IntroGenerics_A_(Ch11)", "sourceLink": "testSource", "pageNumbers": [20]}, {"content": "COSC 121. Page 39\nLiang, Introduction to Java Programming, Tenth Edition, (c) 2015 Pearson Education, Inc. \nPractice\n1) If you change the code in the ensureCapacityfrom\n\u25aaE[] newData = (E[])(new Object[size * 2 + 1]);\nto\n\u25aaE[] newData = (E[])(new Object[size * 2]);\nthe program is incorrect. Can you find the reason?\nHint: consider an ArrayListafter calling clear() then trimToSize()\n2) Add a method to MyArrayListwith the following header:\nintremoveDuplicates()\nThe method should remove all duplicates from the array list. \nAssume that you have a constructor that MyArrayList(intn) \nwhere n is the initial number of elements.", "docName": "L18_implListsStacksQueues_B_(ch24)", "sourceLink": "testSource", "pageNumbers": [37]}], "courseId": "COSC121"}
# With Question Response JSON: {"question": "How should the noDuplicates method handle null values?", "answer": "The noDuplicates method should handle null values by either ignoring them or explicitly removing them from the returned list, depending on the specified requirements.", "sourceDocuments": [{"content": "For A6 Q1, should the noDuplicates method maintain the order of the first occurrence of each element in the list, and how should it handle null values in the input list? Yes, the noDuplicates method should maintain the order of the first occurrence of each element to ensure that the original order is preserved. The method should handle null values by either ignoring them or explicitly removing them from the returned list, depending on the specified requirements.", "sourceLink": "inserted_questions", "pageNumbers": [0]}], "courseId": "COSC121"}
# --------------------------------------------------------------------------------
# Question: What might be wrong with my wind-chill calculation in Java?
# TFIDF Difference: 0.5014402860919627
# No Question Response JSON: {"question": "What might be wrong with my wind-chill calculation in Java?", "answer": "Based on the provided context, I'm going to answer your question.\n\nWhat might be wrong with your wind-chill calculation in Java?\n\nI don't know. The context provides a formula for calculating wind-chill temperature and hints at using Math.pow() for the calculation, but it doesn't provide any specific Java code or errors that might be wrong with the calculation.", "sourceDocuments": [{"content": "A3 [30 marks]  \nFocus: arithmetic operators, Math class, printf () method \nQ1. [6 marks] The evaluation of the cold of our environment relies on several elements such as \nrelative humidity, speed of wind, and sunshine. To calculate the wind-chill temperature using \nwind and temperature, the formula below is used: \n   T\nwc\n = 35.74 + 0.6215 t\na\n - 35.75 v\n0.16\n + 0.4275 t\na\n v\n0.16\n  \nHere, v is the wind speed measured in mph and t\na\n is the exterior temperature measured in \ndegrees Fahrenheit. \n \nDevelop  a  program  that  takes  user  input  for  wind  speed  of  2  or  greater  and  temperature \nwhich is between -58 \u00baF and 41\u00baF and then calculates and prints the wind-chill temperature.  \nAssume the user will always enter a valid value, i.e. within the correct range. \nHint: You can use Math.pow (base value, power value).  \nSample run: \n \nQ2. [6 marks] Write a program that takes a real number as a user input and then prints the digits \nbefore and after the decimal point separately.", "docName": "A03", "sourceLink": "testSource", "pageNumbers": [1]}, {"content": "COSC 111. Page 43\nLiang, Introduction to Java Programming, Tenth Edition, (c) 2015 Pearson Education, Inc. \nPractice\nWrite a program that converts a Fahrenheit degree given by the \nuser to Celsius using the formula:\nAlgorithm:\n\u25aa1. Prompt the user for the Fahrenheit degree. Store the input \nin a variable. \n\u25aa2. Calculate the Celsius equivalent and store it in a variable\n\u25aa3. print out the Celsius degree. \n43\n)\n32\n)(\n(\n9\n5\n\u2212\n=\nfahrenheit\ncelsius\nAnswer:\nScanner input = ...\nSystem.out.println(\"Enter degrees in F\");\ndouble f = input.nextDouble();\ndouble c = (5.0/9) * (f-32);\nSystem.out.println(\"Degrees in C: \" + c);", "docName": "L3_Input_Constrants_Arithmetic_(ch2_part2)", "sourceLink": "testSource", "pageNumbers": [43]}, {"content": "COSC 111. Page 22\nLiang, Introduction to Java Programming, Tenth Edition, (c) 2015 Pearson Education, Inc. \nSimple Java Program 3\nAnimation\nOutput:\n0.39759036144578314", "docName": "L1.2_IntroToComputers_FirstProgram_(ch1_part1)", "sourceLink": "testSource", "pageNumbers": [22]}], "courseId": "COSC111"}
# With Question Response JSON: {"question": "What might be wrong with my wind-chill calculation in Java?", "answer": "I don't know. The provided code seems correct, and the hint is to ensure the input values are within the specified range and correctly typed.", "sourceDocuments": [{"content": "I'm trying to calculate the wind-chill temperature in Java using the formula: `Twc = 35.74 + 0.6215 * ta - 35.75 * Math.pow(v, 0.16) + 0.4275 * ta * Math.pow(v, 0.16)`. Here's my code but I'm not getting the correct output: ``` import java.util.Scanner; public class Q1 { public static void main(String[] args) { Scanner input = new Scanner(System.in); System.out.print(\"Enter the temperature (between -58\u00b0F and 41\u00b0F): \"); double ta = input.nextDouble(); System.out.print(\"Enter the wind speed (2 mph or greater): \"); double v = input.nextDouble(); double Twc = 35.74 + 0.6215 * ta - 35.75 * Math.pow(v, 0.16) + 0.4275 * ta * Math.pow(v, 0.16); System.out.println(\"The wind-chill temperature is \" + Twc); } } ``` Your code looks correct. Ensure the input values are within the specified range and correctly typed. For example: ``` Enter the temperature (between -58\u00b0F and 41\u00b0F): 30 Enter the wind speed (2 mph or greater): 10 ``` This should output: ``` The wind-chill temperature is 21.093000000000004 ```", "sourceLink": "inserted_questions", "pageNumbers": [0]}, {"content": "A3 [30 marks]  \nFocus: arithmetic operators, Math class, printf () method \nQ1. [6 marks] The evaluation of the cold of our environment relies on several elements such as \nrelative humidity, speed of wind, and sunshine. To calculate the wind-chill temperature using \nwind and temperature, the formula below is used: \n   T\nwc\n = 35.74 + 0.6215 t\na\n - 35.75 v\n0.16\n + 0.4275 t\na\n v\n0.16\n  \nHere, v is the wind speed measured in mph and t\na\n is the exterior temperature measured in \ndegrees Fahrenheit. \n \nDevelop  a  program  that  takes  user  input  for  wind  speed  of  2  or  greater  and  temperature \nwhich is between -58 \u00baF and 41\u00baF and then calculates and prints the wind-chill temperature.  \nAssume the user will always enter a valid value, i.e. within the correct range. \nHint: You can use Math.pow (base value, power value).  \nSample run: \n \nQ2. [6 marks] Write a program that takes a real number as a user input and then prints the digits \nbefore and after the decimal point separately.", "docName": "A03", "sourceLink": "testSource", "pageNumbers": [1]}, {"content": "COSC 111. Page 43\nLiang, Introduction to Java Programming, Tenth Edition, (c) 2015 Pearson Education, Inc. \nPractice\nWrite a program that converts a Fahrenheit degree given by the \nuser to Celsius using the formula:\nAlgorithm:\n\u25aa1. Prompt the user for the Fahrenheit degree. Store the input \nin a variable. \n\u25aa2. Calculate the Celsius equivalent and store it in a variable\n\u25aa3. print out the Celsius degree. \n43\n)\n32\n)(\n(\n9\n5\n\u2212\n=\nfahrenheit\ncelsius\nAnswer:\nScanner input = ...\nSystem.out.println(\"Enter degrees in F\");\ndouble f = input.nextDouble();\ndouble c = (5.0/9) * (f-32);\nSystem.out.println(\"Degrees in C: \" + c);", "docName": "L3_Input_Constrants_Arithmetic_(ch2_part2)", "sourceLink": "testSource", "pageNumbers": [43]}], "courseId": "COSC111"}
# --------------------------------------------------------------------------------
# /var/folders/x2/3kx_8_012rjdwr8pb9vgxmcw0000gn/T/ipykernel_20066/4244734193.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_question_df['question'] = no_question_df['response_json'].apply(extract_question)
# /var/folders/x2/3kx_8_012rjdwr8pb9vgxmcw0000gn/T/ipykernel_20066/4244734193.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   with_question_df['question'] = with_question_df['response_json'].apply(extract_question)

# %%
import pandas as pd

CSV_FILE = 'test_results_no_prompt.csv'

fieldnames = [
    'section', 'dataset', 'embedder', 'chunking_detail', 'timestamp', 'extra_info', 'device', 'evalmodel', 'Prompt', 'ModelName',
    'Temperature', 'TopK', 'SimilarityThresholdDocuments',
    'SimilarityThresholdQuestions', 'runId', 'category',
    'TFIDFScore', 'ResponseTime', 'answer_correctness',
    'faithfulness', 'answer_similarity', 'answer_relevancy', 'context_precision',
    'context_relevancy', 'context_recall', 'response_json', 'similarityLevel'
]

# Read the CSV file into a DataFrame
df = pd.read_csv(CSV_FILE, usecols=fieldnames)

# Ensure numeric columns are indeed numeric
numeric_cols = [
    'TFIDFScore', 'ResponseTime', 'answer_similarity', 'answer_correctness'
]

# Convert the specified columns to numeric, coercing errors to NaN
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# Drop rows with NaN values in numeric columns to avoid issues during aggregation
df = df.dropna(subset=numeric_cols)

# Save the comparison DataFrame to a CSV file for further analysis
comparison_df.to_csv('comparison_results.csv', index=False)

dataset_comparison_df = df.groupby(['chunking_details'])[numeric_cols].mean().reset_index()

print(dataset_comparison_df)
# Out:
#   chunking_detail  TFIDFScore  ResponseTime  answer_similarity  \
# 0    no_questions    0.311621   6137.299079           0.677357
# 1  with_questions    0.439530   5128.496131           0.737213
#
#    answer_correctness
# 0            0.500571
# 1            0.655102

# %%
import pandas as pd
import json
CSV_FILE = 'test_results_no_prompt.csv'

fieldnames = [
    'section', 'dataset', 'embedder', 'chunking_detail', 'timestamp', 'extra_info', 'device', 'evalmodel', 'Prompt', 'ModelName',
    'Temperature', 'TopK', 'SimilarityThresholdDocuments',
    'SimilarityThresholdQuestions', 'runId', 'category',
    'TFIDFScore', 'ResponseTime', 'answer_correctness',
    'faithfulness', 'answer_similarity', 'answer_relevancy', 'context_precision',
    'context_relevancy', 'context_recall', 'response_json', 'similarityLevel'
]

# Read the CSV file into a DataFrame
df = pd.read_csv(CSV_FILE, usecols=fieldnames)

# Ensure numeric columns are indeed numeric
numeric_cols = [
    'TFIDFScore', 'ResponseTime', 'answer_similarity', 'answer_correctness'
]
# Parse the 'response_json' to extract the 'answer' field
def extract_answer(json_str):
    try:
        response = json.loads(json_str)
        return response.get('answer', '')
    except json.JSONDecodeError:
        return ''

# Create a new column with the extracted answers
df['extracted_answer'] = df['response_json'].apply(extract_answer)

# Set scores to 0 if the answer contains "I don't know"
condition = df['extracted_answer'].str.contains("I don't know", case=False)
df.loc[condition, numeric_cols] = 0

# Convert the specified columns to numeric, coercing errors to NaN
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# Drop rows with NaN values in numeric columns to avoid issues during aggregation
df = df.dropna(subset=numeric_cols)

dataset_comparison_df = df.groupby(['ModelName'])[numeric_cols].mean().reset_index()

print(dataset_comparison_df)
# Out:
#     ModelName  TFIDFScore  ResponseTime  answer_similarity  answer_correctness
# 0  llama3:70b    0.357617   5774.539585           0.698881            0.556139
